# %%
## # Contact Book

# List to store contact records 
contacts = [
    {"ID": 1, "Name": "Ravi Kumar", "Phone": "9876543210", "Email": "ravi@gmail.com"},
    {"ID": 2, "Name": "Anita Sharma", "Phone": "9123456789", "Email": "anita@gmail.com"},
    {"ID": 3, "Name": "Rahul Verma", "Phone": "9988776655", "Email": "rahul@gmail.com"},
    {"ID": 4, "Name": "Priya Singh", "Phone": "9871234567", "Email": "priya@gmail.com"},
    {"ID": 5, "Name": "Amit Patel", "Phone": "9012345678", "Email": "amit@gmail.com"},
    {"ID": 6, "Name": "Sneha Iyer", "Phone": "9090909090", "Email": "sneha@gmail.com"},
    {"ID": 7, "Name": "Karthik R", "Phone": "8899776655", "Email": "karthik@gmail.com"},
    {"ID": 8, "Name": "Neha Gupta", "Phone": "9345678123", "Email": "neha@gmail.com"},
    {"ID": 9, "Name": "Vikas Malhotra", "Phone": "9765432109", "Email": "vikas@gmail.com"},
    {"ID": 10, "Name": "Pooja Mehta", "Phone": "9555666777", "Email": "pooja@gmail.com"},
    {"ID": 11, "Name": "Arjun Reddy", "Phone": "9887766554", "Email": "arjun@gmail.com"},
    {"ID": 12, "Name": "Kavya Nair", "Phone": "9876655443", "Email": "kavya@gmail.com"},
    {"ID": 13, "Name": "Suresh Babu", "Phone": "9001122334", "Email": "suresh@gmail.com"},
    {"ID": 14, "Name": "Divya Joshi", "Phone": "9120098765", "Email": "divya@gmail.com"},
    {"ID": 15, "Name": "Manoj Yadav", "Phone": "9812345670", "Email": "manoj@gmail.com"},
    {"ID": 16, "Name": "Ayesha Khan", "Phone": "9898989898", "Email": "ayesha@gmail.com"},
    {"ID": 17, "Name": "Rohit Agarwal", "Phone": "9776655443", "Email": "rohit@gmail.com"},
    {"ID": 18, "Name": "Meena Das", "Phone": "9665544332", "Email": "meena@gmail.com"},
    {"ID": 19, "Name": "Nikhil Jain", "Phone": "9443322110", "Email": "nikhil@gmail.com"},
    {"ID": 20, "Name": "Swati Kulkarni", "Phone": "9311223344", "Email": "swati@gmail.com"}
]

# Function to add a contact
def add_contact():
    try:
        contact_id = int(input("Enter Contact ID: "))
        name = input("Enter Contact Name: ").strip().title()
        phone = input("Enter Phone Number: ").strip()
        email = input("Enter Email ID: ").strip().lower()

        contact = {
            "ID": contact_id,
            "Name": name,
            "Phone": phone,
            "Email": email
        }

        contacts.append(contact)
        print("Contact added successfully!")

    except ValueError:
        print("Invalid input! Contact ID must be a number.")

# Function to view all contacts
def view_contacts():
    if len(contacts) == 0:
        print("No contact records found.")
    else:
        print("\n--- Contact Book ---")
        for contact in contacts:
            print("ID:", contact.get("ID"))
            print("Name:", contact.get("Name"))
            print("Phone:", contact.get("Phone"))
            print("Email:", contact.get("Email"))
            print("-------------------")

# Function to search contact by name
def search_contact():
    search_name = input("Enter name to search: ").strip().title()
    found = False
    for contact in contacts:
        if contact.get("Name") == search_name:
            print(contact)
            found = True
    if not found:
        print("No contact found with this name.")

# Function to save contacts to file
def save_to_file():
    with open("contacts.txt", "w") as file:
        for contact in contacts:
            file.write(str(contact) + "\n")
    print("Contact records saved to file.")


while True:
    print("\n===== Contact Book Menu =====")
    print("1. Add Contact")
    print("2. View Contacts")
    print("3. Search Contact by Name")
    print("4. Save & Exit")

    choice = input("Enter your choice (1-4): ").strip()

    if choice == "1":
            add_contact()
    elif choice == "2":
            view_contacts()
    elif choice == "3":
            search_contact()
    elif choice == "4":
        save_to_file()
        print("Exiting program. Thank you!")
        break
    else:
        print("Invalid choice. Please select 1 to 4.")
# Out:
# ===== Contact Book Menu =====
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact by Name
# 4. Save & Exit
# Enter your choice (1-4):  1
# Enter Contact ID:  125
# Enter Contact Name:  someshwar
# Enter Phone Number:  6363969654
# Enter Email ID:  somesh20@gmail.com
# Contact added successfully!
#
# ===== Contact Book Menu =====
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact by Name
# 4. Save & Exit
# Enter your choice (1-4):  2
# --- Contact Book ---
# ID: 1
# Name: Ravi Kumar
# Phone: 9876543210
# Email: ravi@gmail.com
# -------------------
# ID: 2
# Name: Anita Sharma
# Phone: 9123456789
# Email: anita@gmail.com
# -------------------
# ID: 3
# Name: Rahul Verma
# Phone: 9988776655
# Email: rahul@gmail.com
# -------------------
# ID: 4
# Name: Priya Singh
# Phone: 9871234567
# Email: priya@gmail.com
# -------------------
# ID: 5
# Name: Amit Patel
# Phone: 9012345678
# Email: amit@gmail.com
# -------------------
# ID: 6
# Name: Sneha Iyer
# Phone: 9090909090
# ...
